# %% [markdown]
# # Building Segmentantation Experiments - Ukrainian Cities finetuning

# %% [markdown]
# ## Requirements

# %%
# %%writefile requirements.txt
# torch
# torchvision
# matplotlib
# numpy
# pandas
# tqdm
# opencv-python
# albumentations
# segmentation_models_pytorch
# tensorboard
# Out:
# Writing requirements.txt

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 102.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 90.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 84.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 13.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %% [markdown]
# ## Imports

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import sys
sys.path.append('/content/drive/MyDrive/thesis_code/segmentation')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import torch
import cv2
import numpy as np
import matplotlib.pyplot as plt

from scripts.transforms import get_train_transform, get_test_transform
from scripts.k_folds import run_kfold_segmentation_experiments
from scripts.models import UNet
from scripts.loss import HybridLoss

# %% [markdown]
# ## Data Retrieval

# %%
# !unzip "/content/drive/MyDrive/thesis_code/segmentation/data/kamianka_pre_segm_folds.zip"
# !mv data kamianka_data
# !unzip "/content/drive/MyDrive/thesis_code/segmentation/data/yakovlivka_pre_segm_folds.zip"
# !mv data yakovlivka_data
# !unzip "/content/drive/MyDrive/thesis_code/segmentation/data/popasna_pre_segm_folds.zip"
# !mv data popasna_data
# Out:
# Archive:  /content/drive/MyDrive/thesis_code/segmentation/data/kamianka_pre_segm_folds.zip
#    creating: data/
#    creating: data/fold_1/
#    creating: data/fold_1/images/
#   inflating: data/fold_1/images/tile_5_4.tif
#   inflating: data/fold_1/images/tile_5_6.tif
#   inflating: data/fold_1/images/tile_7_7.tif
#   inflating: data/fold_1/images/tile_4_2.tif
#   inflating: data/fold_1/images/tile_2_4.tif
#   inflating: data/fold_1/images/tile_9_3.tif
#    creating: data/fold_1/targets/
#   inflating: data/fold_1/targets/tile_9_3.png
#   inflating: data/fold_1/targets/tile_5_6.png
#   inflating: data/fold_1/targets/tile_7_7.png
#   inflating: data/fold_1/targets/tile_5_4.png
#   inflating: data/fold_1/targets/tile_4_2.png
#   inflating: data/fold_1/targets/tile_2_4.png
#    creating: data/fold_4/
#    creating: data/fold_4/images/
#   inflating: data/fold_4/images/tile_2_5.tif
#   inflating: data/fold_4/images/tile_8_6.tif
#   inflating: data/fold_4/images/tile_8_2.tif
# ...

# %% [markdown]
# ## Experiments

# %% [markdown]
# ### Kamianka

# %%
df_kamianka = run_kfold_segmentation_experiments(
    DATA_DIR='/content/kamianka_data/',
    train_transform=get_train_transform(use_crop=False, use_color_transforms=True),
    test_transform=get_test_transform(min_size=(1024, 1024)),
    model_class=UNet,
    loss_fn=HybridLoss(),
    checkpoint_path='/content/drive/MyDrive/thesis_code/segmentation/models/model_UNet_XView_40.pt',
)
# Out:
# /content/drive/MyDrive/thesis_code/segmentation/scripts/transforms.py:69: UserWarning: Argument(s) 'always_apply, value' are not valid for transform PadIfNeeded
#   A.PadIfNeeded(min_height=min_size[0], min_width=min_size[1], always_apply=True,
# === Fold 1 | Test folds: [0, 1] ===
# Training...
# Epoch 1/10
# ...
# 100%|██████████| 12/12 [00:08<00:00,  1.48it/s]
# Epoch 1:
#   Train Loss: 0.1919, Precision: 0.7186, Recall: 0.7516, F1: 0.7247, IoU: 0.5748
#   Val Loss: 0.1139, Precision: 0.7776, Recall: 0.7591, F1: 0.7623, IoU: 0.6557
# Epoch 2/10
# ...
# 100%|██████████| 12/12 [00:08<00:00,  1.37it/s]
# Epoch 2:
#   Train Loss: 0.1609, Precision: 0.7526, Recall: 0.7976, F1: 0.7708, IoU: 0.6304
#   Val Loss: 0.1070, Precision: 0.7572, Recall: 0.7961, F1: 0.7730, IoU: 0.6710
# Epoch 3/10
# ...
# 100%|██████████| 12/12 [00:07<00:00,  1.50it/s]
# Epoch 3:
#   Train Loss: 0.1473, Precision: 0.7828, Recall: 0.8038, F1: 0.7876, IoU: 0.6535
# ...

# %%
output_path = '/content/drive/MyDrive/thesis_code/segmentation/results/df_kamianka.csv'
df_kamianka.to_csv(output_path, index=False)
print(f"\nSaved results to: {output_path}")
# Out:
# Saved results to: /content/drive/MyDrive/thesis_code/segmentation/results/df_kamianka.csv

# %% [markdown]
# ### Yakovlivka

# %%
df_yakovlivka = run_kfold_segmentation_experiments(
    DATA_DIR='/content/yakovlivka_data/',
    train_transform=get_train_transform(use_crop=False, use_color_transforms=True),
    test_transform=get_test_transform(min_size=(1024, 1024)),
    model_class=UNet,
    loss_fn=HybridLoss(),
    checkpoint_path='/content/drive/MyDrive/thesis_code/segmentation/models/model_UNet_XView_40.pt',
)
# Out:
# /content/drive/MyDrive/thesis_code/segmentation/scripts/transforms.py:69: UserWarning: Argument(s) 'always_apply, value' are not valid for transform PadIfNeeded
#   A.PadIfNeeded(min_height=min_size[0], min_width=min_size[1], always_apply=True,
# === Fold 1 | Test folds: [0, 1] ===
# Training...
# Epoch 1/10
# ...
# 100%|██████████| 8/8 [00:05<00:00,  1.45it/s]
# Epoch 1:
#   Train Loss: 0.3794, Precision: 0.6429, Recall: 0.6482, F1: 0.6287, IoU: 0.4777
#   Val Loss: 0.1620, Precision: 0.6665, Recall: 0.6842, F1: 0.6728, IoU: 0.5531
# Epoch 2/10
# ...
# 100%|██████████| 8/8 [00:05<00:00,  1.40it/s]
# Epoch 2:
#   Train Loss: 0.2212, Precision: 0.7552, Recall: 0.7681, F1: 0.7560, IoU: 0.6212
#   Val Loss: 0.1568, Precision: 0.6551, Recall: 0.7139, F1: 0.6756, IoU: 0.5596
# Epoch 3/10
# ...
# 100%|██████████| 8/8 [00:06<00:00,  1.32it/s]
# Epoch 3:
#   Train Loss: 0.1872, Precision: 0.8089, Recall: 0.7999, F1: 0.7999, IoU: 0.6732
# ...

# %%
output_path = '/content/drive/MyDrive/thesis_code/segmentation/results/df_yakovlivka.csv'
df_yakovlivka.to_csv(output_path, index=False)
print(f"\nSaved results to: {output_path}")
# Out:
# Saved results to: /content/drive/MyDrive/thesis_code/segmentation/results/df_yakovlivka.csv

# %% [markdown]
# ### Popasna

# %%
df_popasna = run_kfold_segmentation_experiments(
    DATA_DIR='/content/popasna_data/',
    train_transform=get_train_transform(use_crop=False, use_color_transforms=True),
    test_transform=get_test_transform(min_size=(1024, 1024)),
    model_class=UNet,
    loss_fn=HybridLoss(),
    checkpoint_path='/content/drive/MyDrive/thesis_code/segmentation/models/model_UNet_XView_40.pt',
)
# Out:
# /content/drive/MyDrive/thesis_code/segmentation/scripts/transforms.py:69: UserWarning: Argument(s) 'always_apply, value' are not valid for transform PadIfNeeded
#   A.PadIfNeeded(min_height=min_size[0], min_width=min_size[1], always_apply=True,
# === Fold 1 | Test folds: [0, 1] ===
# Training...
# Epoch 1/10
# ...
# 100%|██████████| 12/12 [00:07<00:00,  1.65it/s]
# Epoch 1:
#   Train Loss: 0.3895, Precision: 0.6284, Recall: 0.6061, F1: 0.6083, IoU: 0.4442
#   Val Loss: 0.2948, Precision: 0.5663, Recall: 0.6955, F1: 0.6225, IoU: 0.4772
# Epoch 2/10
# ...
# 100%|██████████| 12/12 [00:08<00:00,  1.47it/s]
# Epoch 2:
#   Train Loss: 0.3259, Precision: 0.6889, Recall: 0.6750, F1: 0.6757, IoU: 0.5142
#   Val Loss: 0.2655, Precision: 0.6355, Recall: 0.6614, F1: 0.6450, IoU: 0.5031
# Epoch 3/10
# ...
# 100%|██████████| 12/12 [00:07<00:00,  1.51it/s]
# Epoch 3:
#   Train Loss: 0.3156, Precision: 0.7104, Recall: 0.6651, F1: 0.6822, IoU: 0.5235
# ...

# %%
output_path = '/content/drive/MyDrive/thesis_code/segmentation/results/df_popasna.csv'
df_popasna.to_csv(output_path, index=False)
print(f"\nSaved results to: {output_path}")
# Out:
# Saved results to: /content/drive/MyDrive/thesis_code/segmentation/results/df_popasna.csv
